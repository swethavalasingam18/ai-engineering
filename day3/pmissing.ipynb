# %%
import pandas as pd
import numpy as np

data = {
    'name': ['Amit', 'Priya', 'Amit', 'Ravi', 'Sneha', None, 'Ravi'],
    'age': [25, 30, 25, np.nan, 28, 35, 40],
    'city': ['Hyderabad', 'Pune', 'Hyderabad', 'Delhi', None, 'Mumbai', 'Delhi'],
    'salary': [45000, 60000, 45000, 55000, 50000, 70000, 55000]
    
}
df = pd.DataFrame(data)
df
# Out:
#     name   age       city  salary
# 0   Amit  25.0  Hyderabad   45000
# 1  Priya  30.0       Pune   60000
# 2   Amit  25.0  Hyderabad   45000
# 3   Ravi   NaN      Delhi   55000
# 4  Sneha  28.0        NaN   50000
# 5    NaN  35.0     Mumbai   70000
# 6   Ravi  40.0      Delhi   55000

# %%
df.isna().sum()
# Out:
# name      1
# age       1
# city      1
# salary    0
# dtype: int64

# %%
df['age'] = df['age'].fillna(0)
df['name'] = df['name'].fillna('Unknown')
df['city'] = df['city'].fillna('Unknown')
df
# Out:
#       name   age       city  salary
# 0     Amit  25.0  Hyderabad   45000
# 1    Priya  30.0       Pune   60000
# 2     Amit  25.0  Hyderabad   45000
# 3     Ravi   0.0      Delhi   55000
# 4    Sneha  28.0    Unknown   50000
# 5  Unknown  35.0     Mumbai   70000
# 6     Ravi  40.0      Delhi   55000

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()
df
# Out:
#       name   age       city  salary
# 0     Amit  25.0  Hyderabad   45000
# 1    Priya  30.0       Pune   60000
# 3     Ravi   0.0      Delhi   55000
# 4    Sneha  28.0    Unknown   50000
# 5  Unknown  35.0     Mumbai   70000
# 6     Ravi  40.0      Delhi   55000

# %%
# %%
df.groupby('city').size()
# Out:
# city
# Delhi        2
# Hyderabad    1
# Mumbai       1
# Pune         1
# Unknown      1
# dtype: int64

# %%
# %%
df.groupby('city')['salary'].sum()
# Out:
# city
# Delhi        110000
# Hyderabad     45000
# Mumbai        70000
# Pune          60000
# Unknown       50000
# Name: salary, dtype: int64

# %%
# %%
df.groupby('city')['salary'].max()
# Out:
# city
# Delhi        55000
# Hyderabad    45000
# Mumbai       70000
# Pune         60000
# Unknown      50000
# Name: salary, dtype: int64

# %%
df.sort_values('salary')
# Out:
#       name   age       city  salary
# 0     Amit  25.0  Hyderabad   45000
# 4    Sneha  28.0    Unknown   50000
# 3     Ravi   0.0      Delhi   55000
# 6     Ravi  40.0      Delhi   55000
# 1    Priya  30.0       Pune   60000
# 5  Unknown  35.0     Mumbai   70000

# %%
df.sort_values('salary' ,ascending=False)
# Out:
#       name   age       city  salary
# 5  Unknown  35.0     Mumbai   70000
# 1    Priya  30.0       Pune   60000
# 6     Ravi  40.0      Delhi   55000
# 3     Ravi   0.0      Delhi   55000
# 4    Sneha  28.0    Unknown   50000
# 0     Amit  25.0  Hyderabad   45000

# %%
df.sort_values(['city' ,'salary'],ascending =[True , False])
# Out:
#       name   age       city  salary
# 3     Ravi   0.0      Delhi   55000
# 6     Ravi  40.0      Delhi   55000
# 0     Amit  25.0  Hyderabad   45000
# 5  Unknown  35.0     Mumbai   70000
# 1    Priya  30.0       Pune   60000
# 4    Sneha  28.0    Unknown   50000
