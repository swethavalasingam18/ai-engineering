# %%
# %%
import pandas as pd
import numpy as np

# Simulated e-commerce order data
data = {
    'order_value': [450, 500, 480, 520, 470, 510, 490, 15000, 460, 505],
    'delivery_days': [2, 3, 2, 4, 3, 2, 3, 5, 2, 3],
    'customer_age': [25, 34, 29, 45, 31, 28, 38, 50, 26, 33]
}
df = pd.DataFrame(data)
df
# Out:
#    order_value  delivery_days  customer_age
# 0          450              2            25
# 1          500              3            34
# 2          480              2            29
# 3          520              4            45
# 4          470              3            31
# 5          510              2            28
# 6          490              3            38
# 7        15000              5            50
# 8          460              2            26
# 9          505              3            33

# %%
# %%
print("Mean order value:", df['order_value'].mean())
print("Median order value:", df['order_value'].median())
print("Std dev order value:", df['order_value'].std())
# Out:
# Mean order value: 1938.5
# Median order value: 495.0
# Std dev order value: 4589.398441577671

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\SWITHIN\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# %%
df['order_value'].hist(bins=10)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
# %%
df.corr()
# Out:
#                order_value  delivery_days  customer_age
# order_value       1.000000       0.743978      0.690268
# delivery_days     0.743978       1.000000      0.963115
# customer_age      0.690268       0.963115      1.000000

# %%
# %%
df_no_outlier = df[df['order_value'] < 1000]  # drops the 15000 row
print(df_no_outlier.corr())
# Out:
#                order_value  delivery_days  customer_age
# order_value       1.000000       0.604984      0.709458
# delivery_days     0.604984       1.000000      0.930404
# customer_age      0.709458       0.930404      1.000000
